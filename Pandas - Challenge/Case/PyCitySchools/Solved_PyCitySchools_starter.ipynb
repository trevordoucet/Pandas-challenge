# %% [markdown]
# # PyCity Schools Analysis
#
# * As a whole, schools with higher budgets, did not yield better test results. By contrast, schools with higher spending per student actually (\$645-675) underperformed compared to schools with smaller budgets (<\$585 per student).
#
# * As a whole, smaller and medium sized schools dramatically out-performed large sized schools on passing math performances (89-91% passing vs 67%).
#
# * As a whole, charter schools out-performed the public district schools across all metrics. However, more analysis will be required to glean if the effect is due to school practices or the fact that charter schools tend to serve smaller student populations per school.
# ---

# %%
# Dependencies and Setup
import pandas as pd

# File to Load 
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset (consider using a left join)
school_student = school_data.merge(student_data, left_on="school_name", right_on="school_name")
school_student.head()
# Out:
#    School ID        school_name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#         student_name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %% [markdown]
# ## District Summary

# %%
# Calculate the Totals (Schools and Students)
total_students = len(school_student["student_name"])


total_schools = school_student.groupby("school_name")["school_name"].nunique()
total_schools.sum()

# Calculate the Total Budget
budget_total = school_student[["school_name","budget"]].drop_duplicates()
budget_total["budget"].sum()

# Calculate the Average Scores
avg_math = school_student["math_score"]
avg_math.mean()

avg_read = school_student["reading_score"]
##avg_read.mean_()
# Calculate the Percentage Pass Rates

reading_pass = school_student["reading_score"]>=70
reading_pass = reading_pass.sum()

reading_pass = reading_pass/total_students
reading_pass

math_pass = school_student["math_score"]>=70
math_pass = math_pass.sum()

math_pass = math_pass/total_students
math_pass

both_pass = len(school_student[(school_student["reading_score"]>=70)&(school_student["math_score"]>=70)])

both_pass = both_pass/total_students
both_pass


# Minor Data Cleanup

# Display the data frame
school_student
# Out:
#        School ID         school_name      type  size   budget  Student ID  \
# 0              0   Huang High School  District  2917  1910635           0
# 1              0   Huang High School  District  2917  1910635           1
# 2              0   Huang High School  District  2917  1910635           2
# 3              0   Huang High School  District  2917  1910635           3
# 4              0   Huang High School  District  2917  1910635           4
# 5              0   Huang High School  District  2917  1910635           5
# 6              0   Huang High School  District  2917  1910635           6
# 7              0   Huang High School  District  2917  1910635           7
# 8              0   Huang High School  District  2917  1910635           8
# 9              0   Huang High School  District  2917  1910635           9
# 10             0   Huang High School  District  2917  1910635          10
# 11             0   Huang High School  District  2917  1910635          11
# ...

# %% [markdown]
# ## School Summary

# %%
# Determine the School Type
school_type = school_student["type"]
school_type = school_student[["school_name","type"]].drop_duplicates()
school_type

# Calculate the total student count
school_type = school_student[["school_name","type","size"]].drop_duplicates()
school_type.index=school_type.school_name

# Calculate the total school budget and per capita spending
#per_school_budget = school_data_complete.groupby(["school_name"]).mean()["budget"]
school_type = school_student[["school_name","type","size","budget"]].drop_duplicates()
school_type["per_student_budget"] = school_type["budget"]/school_type["size"]
school_type=school_type.set_index("school_name")
#school_type
# Calculate the average test scores
average_scores = school_student.groupby("school_name")[["reading_score", "math_score"]].mean()
average_scores

school_df = pd.merge(school_type,average_scores, left_index=True, right_index=True)

#school_df
# Calculate the passing scores by creating a filtered data frame

pass_math = school_student[school_student.math_score>=70]
pass_math = pass_math.groupby("school_name")["math_score"].count()
school_type["number_passed_math"]= pass_math
school_type["Math Pass Rate"] = school_type["number_passed_math"]/school_type["size"]*100
#school_type

pass_read = school_student[school_student.reading_score>=70]
pass_read = pass_read.groupby("school_name")["reading_score"].count()
school_type["number_passed_read"]= pass_read
school_type["Reading Pass Rate"] = school_type["number_passed_read"]/school_type["size"]*100
#school_type

Overall_Rate = (school_type["Reading Pass Rate"] + school_type["Math Pass Rate"])/2
school_type["Overall_Rate"] = (school_type["Math Pass Rate"] + school_type["Reading Pass Rate"])/2

school_type_df = pd.merge(school_type, average_scores, how="left", on="school_name")
school_final = school_type_df.rename(columns = {"per_student_budget":"Student Budget","number_passed_math": "Passed Math", "number_passed_read": "Passed Reading", "reading_score": "Average Reading Score","math_score":"Average Math Score"})
school_final
# Convert to data frame

# Minor data munging

# Display the data frame
# Out:
#                            type  size   budget  Student Budget  Passed Math  \
# school_name
# Huang High School      District  2917  1910635           655.0         1916
# Figueroa High School   District  2949  1884411           639.0         1946
# Shelton High School     Charter  1761  1056600           600.0         1653
# Hernandez High School  District  4635  3022020           652.0         3094
# Griffin High School     Charter  1468   917500           625.0         1371
# Wilson High School      Charter  2283  1319574           578.0         2143
# Cabrera High School     Charter  1858  1081356           582.0         1749
# Bailey High School     District  4976  3124928           628.0         3318
# Holden High School      Charter   427   248087           581.0          395
# Pena High School        Charter   962   585858           609.0          910
# Wright High School      Charter  1800  1049400           583.0         1680
# ...

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)
#
# # Sort and show top five schools
# best_five = school_type.sort_values("Math Pass Rate", ascending=False)
# best_five.head(5)

# %%
best_five = school_final.sort_values("Overall_Rate", ascending=False) 
best_five.head(5)
# Out:
#                         type  size   budget  Student Budget  Passed Math  \
# school_name
# Cabrera High School  Charter  1858  1081356           582.0         1749
# Thomas High School   Charter  1635  1043130           638.0         1525
# Pena High School     Charter   962   585858           609.0          910
# Griffin High School  Charter  1468   917500           625.0         1371
# Wilson High School   Charter  2283  1319574           578.0         2143
#
#                      Math Pass Rate  Passed Reading  Reading Pass Rate  \
# school_name
# Cabrera High School       94.133477            1803          97.039828
# Thomas High School        93.272171            1591          97.308869
# Pena High School          94.594595             923          95.945946
# Griffin High School       93.392371            1426          97.138965
# Wilson High School        93.867718            2204          96.539641
#
# ...

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %%
# Sort and show bottom five schools
best_five = school_final.sort_values("Overall_Rate", ascending=True) 
best_five.head(5)
# Out:
#                            type  size   budget  Student Budget  Passed Math  \
# school_name
# Rodriguez High School  District  3999  2547363           637.0         2654
# Figueroa High School   District  2949  1884411           639.0         1946
# Huang High School      District  2917  1910635           655.0         1916
# Johnson High School    District  4761  3094650           650.0         3145
# Ford High School       District  2739  1763916           644.0         1871
#
#                        Math Pass Rate  Passed Reading  Reading Pass Rate  \
# school_name
# Rodriguez High School       66.366592            3208          80.220055
# Figueroa High School        65.988471            2381          80.739234
# Huang High School           65.683922            2372          81.316421
# Johnson High School         66.057551            3867          81.222432
# Ford High School            68.309602            2172          79.299014
#
# ...

# %% [markdown]
# ## Math Scores by Grade

# %%
# Create data series of scores by grade levels using conditionals
ninth_grade = school_student["grade"] == "9th"
score_ninth = school_student.loc[ninth_grade]
group_ninth = score_ninth.groupby(["school_name"])
grading_ninth = group_ninth["math_score"].mean()
grading_ninth

tenth_grade = school_student["grade"] == "10th"
score_tenth = school_student.loc[tenth_grade]
group_tenth = score_tenth.groupby(["school_name"])
grading_tenth = group_tenth["math_score"].mean()
grading_tenth

eleven_grade = school_student["grade"] == "11th"
score_eleven = school_student.loc[eleven_grade]
group_eleven = score_eleven.groupby(["school_name"])
grading_eleven = group_eleven["math_score"].mean()
grading_eleven

twelth_grade = school_student["grade"] == "12th"
score_twelth = school_student.loc[twelth_grade]
group_twelth = score_twelth.groupby(["school_name"])
grading_twelth = group_twelth["math_score"].mean()
grading_twelth

grade_value = {"9th":grading_ninth, "10th":grading_tenth,"11th":grading_tenth,"12th":grading_twelth}
score = pd.DataFrame(grade_value)
score

# Group each by school name

# Combine series into single data frame

# Minor data munging

# Display the data frame
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  76.996772  76.492218
# Cabrera High School    83.094697  83.154506  83.154506  83.277487
# Figueroa High School   76.403037  76.539974  76.539974  77.151369
# Ford High School       77.361345  77.672316  77.672316  76.179963
# Griffin High School    82.044010  84.229064  84.229064  83.356164
# Hernandez High School  77.438495  77.337408  77.337408  77.186567
# Holden High School     83.787402  83.429825  83.429825  82.855422
# Huang High School      77.027251  75.908735  75.908735  77.225641
# Johnson High School    77.187857  76.691117  76.691117  76.863248
# Pena High School       83.625455  83.372000  83.372000  84.121547
# Rodriguez High School  76.859966  76.612500  76.612500  77.690748
# Shelton High School    83.420755  82.917411  82.917411  83.778976
# Thomas High School     83.590022  83.087886  83.087886  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %%
# Create data series of scores by grade levels using conditionals
ninth_grade = school_student["grade"] == "9th"
ninth_grade = school_student == "9th"
score_ninth = school_student.loc[ninth_grade]
group_ninth = score_ninth.groupby(["school_name"])
grading_ninth = group_ninth["reading_score"].mean()
grading_ninth

tenth_grade = school_student["grade"] == "10th"
score_tenth = school_student.loc[tenth_grade]
group_tenth = score_tenth.groupby(["school_name"])
grading_tenth = group_tenth["reading_score"].mean()
grading_tenth

eleven_grade = school_student["grade"] == "11th"
score_eleven = school_student.loc[eleven_grade]
group_eleven = score_eleven.groupby(["school_name"])
grading_eleven = group_eleven["reading_score"].mean()
grading_eleven

twelth_grade = school_student["grade"] == "12th"
score_twelth = school_student.loc[twelth_grade]
group_twelth = score_twelth.groupby(["school_name"])
grading_twelth = group_twelth["reading_score"].mean()
grading_twelth

grade_value = {"9th":grading_ninth, "10th":grading_tenth,"11th":grading_tenth,"12th":grading_twelth}
score = pd.DataFrame(grade_value)
score
# Group each by school name

# Combine series into single data frame

# Minor data munging

# Display the data frame
# Out:
# /Users/trevordoucet/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-23b24dd7c3d8> in <module>
#       2 ninth_grade = school_student["grade"] == "9th"
#       3 ninth_grade = school_student == "9th"
# ----> 4 score_ninth = school_student.loc[ninth_grade]
#       5 group_ninth = score_ninth.groupby(["school_name"])
#       6 grading_ninth = group_ninth["reading_score"].mean()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
# ...

# %% [markdown]
# ## Scores by School Spending

# %%
# Establish the bins -- choose any set of bins you would like, but see below for testing bins
# to test, set your bins as follows: [0, 585, 615, 645, 675]
# ALSO -- Note that the values for `% Passing Math`, `% Passing Reading` and `% Overall Passing Rate`
# were computed using averages of averages -- your results may vary if you use weighted averages 
budget_bin = [0, 585, 615, 645, 675]
budget_labels = [" < $585","$585 - 615","$615 - 645", "$645 - 675"]
school_final["Student Budget"] = pd.cut(school_final)["Student Budget"],budget_bin,labels = budget_labels
spend_group = school_final.groupby(["Student Budget"]).mean()

average_math = school_final.groupby(["Student Budget"]).mean()["Average Math Score"]
average_reading = school_final.groupby(["Student Budget"]).mean()["Average Reading Score"]
passing_math = school_final.groupby(["Student Budget"]).mean()["Math Pass Rate"]
passing_reading = school_final.groupby(["Student Budget"]).mean()["Reading Pass Rate"]
overall = (passing_math + passing_reading) / 2

spend_group = pd.DataFrame({"Average Math Score" : average_math,
      "Average Reading Score": average_reading,
      "Reading Pass Rate": passing_reading,
      "Math Pass Rate": passing_math,
      "Overall_Rate":overall})


spend_group

# Categorize the spending based on the bins

# Assemble into data frame

# Minor data munging

# Display results
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-527778bf5efa> in <module>
#       5 budget_bin = [0, 585, 615, 645, 675]
#       6 budget_labels = [" < $585","$585 - 615","$615 - 645", "$645 - 675"]
# ----> 7 school_final["Student Budget"] = pd.cut(school_final)["Student Budget"],budget_bin,labels = budget_labels
#       8 spend_group = school_final.groupby(["Student Budget"]).mean()
#       9
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# ...

# %% [markdown]
# ## Scores by School Size

# %%
# Establish the bins 
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]
# Categorize the spending based on the bins
school_final["size"] = pd.cut(school_final["size"], size_bins, labels=group_names)
# Calculate the scores based on bins
average_math = school_final.groupby(["size"]).mean()["Average Math Score"]
average_reading = school_final.groupby(["size"]).mean()["Average Reading Score"]
passing_math = school_final.groupby(["size"]).mean()["Math Pass Rate"]
passing_reading = school_final.groupby(["size"]).mean()["Reading Pass Rate"]
overall = (passing_math + passing_reading) / 2

size_summary = pd.DataFrame({"Average Math Score":average_math,
      "Average Reading Score": average_reading,
      "Math Pass Rate": passing_math,
      "Reading Pass Rate": passing_reading,
      "Overall_Rate": overall})

size_summary
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-b063584e8886> in <module>
#       3 group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]
#       4 # Categorize the spending based on the bins
# ----> 5 school_final["size"] = pd.cut(school_final["size"], size_bins, labels=group_names)
#       6 # Calculate the scores based on bins
#       7 average_math = school_final.groupby(["size"]).mean()["Average Math Score"]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     239                               include_lowest=include_lowest,
#     240                               dtype=dtype,
# --> 241                               duplicates=duplicates)
#     242
#     243     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# ...

# %% [markdown]
# ## Scores by School Type

# %%
# Type | Average Math Score | Average Reading Score | % Passing Math | % Passing Reading | % Overall Passing Rate

average_math = school_final.groupby(["type"]).mean()["Average Math Score"]
average_reading = school_final.groupby(["type"]).mean()["Average Reading Score"]
passing_math = school_final.groupby(["type"]).mean()["Math Pass Rate"]
passing_reading = school_final.groupby(["type"]).mean()["Reading Pass Rate"]
overall = (passing_math + passing_reading) / 2

type_summary = pd.DataFrame({"Average Math Score":average_math,
      "Average Reading Score": average_reading,
      "Reading Pass Rate": passing_reading,
      "Math Pass Rate": passing_math,
      "Overall_Rate": overall})

type_summary

# Assemble into data frame

# Minor data munging

# Display results
# Out:
#           Average Math Score  Average Reading Score  Reading Pass Rate  \
# type
# Charter            83.473852              83.896421          96.586489
# District           76.956733              80.966636          80.799062
#
#           Math Pass Rate  Overall_Rate
# type
# Charter        93.620830     95.103660
# District       66.548453     73.673757
